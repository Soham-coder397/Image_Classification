# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_train_path = r'Fruits_Vegitables\train'
data_test_path = r'Fruits_Vegitables\test'
data_val_path = r'Fruits_Vegitables\validation'

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False)
# Out:
# Found 108 files belonging to 27 classes.

# %%
data_cat = data_train.class_names
# Out:
# ['Apple',
#  'Banana',
#  'Bell_Pepper',
#  'Blackberry',
#  'Brinjal',
#  'Cabbage',
#  'Carrot',
#  'Cherry',
#  'Chili_Pepper',
#  'Coconut',
#  'Cucumber',
#  'Garlic',
#  'Grape',
#  'Green_Peas',
#  'Guava',
#  'Lemon',
#  'Mango',
#  'Onion',
#  'Orange',
#  'Papaya',
#  'Pinaple',
#  'Potato',
#  'Pumpkin',
#  'Radish',
#  'Strawberry',
#  'Tomato',
#  'Watermelon']

# %%
data_cat = data_train.class_names

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    image_size = (img_height,img_width),
    batch_size = 32,
    shuffle = False,
    validation_split = False
)
# Out:
# Found 108 files belonging to 27 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    image_size = (img_height,img_width),
    batch_size = 32,
    shuffle = False,
    validation_split = False
)
# Out:
# Found 108 files belonging to 27 classes.

# %%
plt.figure(figsize=(10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16,3,padding='same',activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(units = len(data_cat))
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model = Sequential([
#       2     layers.Rescaling(1./255),
#       3     layers.Conv2D(16,3,padding='same',activation = 'relu'),
#       4     layers.MaxPooling2D(),
#
# NameError: name 'Sequential' is not defined
